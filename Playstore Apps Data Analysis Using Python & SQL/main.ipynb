# %%
import sys
import io
import numpy as np
import traceback
import re
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
import Task1 as user
#import playstore_data as user
import io
import numpy as np
import traceback
import re
import pandas as pd




def test1():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.read_data_from_csv()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.read_data_from_csv()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message


def test2():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    try:
        output = user.remove_unwanted_columns().columns
        test_output = test.remove_unwanted_columns().columns
        if test_output.equals(output):
            ispassed = True
        if not ispassed:
            print("<b>Columns are not matching with expected result</b>")
        print("No. of values in Your Output: ")
        print(len(output))
        print("\nNo. of values in Expected Output: ")
        print(len(test_output))
        print("Your Output: ")
        print(output)
        print("\nExpected Output: ")
        print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message



def test3():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.remove_duplicates()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.remove_duplicates()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message



def test4():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""

    try:
        output = None
        try:
            # output = user.load_dataset()
            output = user.no_of_null_values()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        test_output = None
        try:
            test_output = test.no_of_null_values()
            # test_output = None
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output) != len(test_output):
            message1 = "Your output is not matching with the expected output"
            print(message1)
            print("No. of values in Your Output: ")
            print(len(output))
            print("\nNo. of values in Expected Output: ")
            print(len(test_output))
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        # elif output.shape[0] != test_output.shape[0]:
        #     message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
        #     print(message1)
        #     print("Your rows count:")
        #     print(output.shape[0])
        #     print("Expected rows count:")
        #     print(test_output.shape[0])
        #     print("Your Output: ")
        #     print(output)
        #     print("\nExpected Output: ")
        #     print(test_output)
        elif test_output.equals(output):
            ispassed = True
            print("---------------------------------------------")
            print("No. of Rows in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
        else:
            print("<b>Your Dataframe does not match the expected output</b>")
            print("No. of Rows in Your Dataframe: " + str(output.shape))
            print("---------------------------------------------")
            print("No. of Rows in Expected Dataframe: " + str(test_output.shape))
            print("Your Updated results: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
            diff = pd.concat([output.stack(), test_output.stack()], axis=1)
            diff.columns = ['users', 'expected']
            diff['equal'] = diff['users'].eq(diff['expected'])
            diff = diff[diff['equal'] == False]
            pd.set_option('display.max_rows', None)
            pd.set_option('display.max_columns', None)
            print("<b>Data Differences:</b>")
            print("*" * 25)
            print(diff.drop_duplicates())

    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
        pass
    sys.stdout = sys.__stdout__
    message += op.getvalue()
    return ispassed, message



def test5():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.replace_null_values()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.replace_null_values()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message


def test6():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.check_unique_values()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.check_unique_values()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message



def test7():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""

    try:
        output = None
        try:
            # output = user.load_dataset()
            output = user.free_or_paid()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        test_output = None
        try:
            test_output = test.free_or_paid()
            # test_output = None
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output) != len(test_output):
            message1 = "Your output is not matching with the expected output"
            print(message1)
            print("No. of values in Your Output: ")
            print(len(output))
            print("\nNo. of values in Expected Output: ")
            print(len(test_output))
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        # elif output.shape[0] != test_output.shape[0]:
        #     message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
        #     print(message1)
        #     print("Your rows count:")
        #     print(output.shape[0])
        #     print("Expected rows count:")
        #     print(test_output.shape[0])
        #     print("Your Output: ")
        #     print(output)
        #     print("\nExpected Output: ")
        #     print(test_output)
        elif test_output.equals(output):
            ispassed = True
            print("---------------------------------------------")
            print("No. of Rows in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
        else:
            print("<b>Your Dataframe does not match the expected output</b>")
            print("No. of Rows in Your Dataframe: " + str(output.shape))
            print("---------------------------------------------")
            print("No. of Rows in Expected Dataframe: " + str(test_output.shape))
            print("Your Updated results: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
            diff = pd.concat([output.stack(), test_output.stack()], axis=1)
            diff.columns = ['users', 'expected']
            diff['equal'] = diff['users'].eq(diff['expected'])
            diff = diff[diff['equal'] == False]
            pd.set_option('display.max_rows', None)
            pd.set_option('display.max_columns', None)
            print("<b>Data Differences:</b>")
            print("*" * 25)
            print(diff.drop_duplicates())

    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
        pass
    sys.stdout = sys.__stdout__
    message += op.getvalue()
    return ispassed, message

#irrleveant_names()

def test8():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.irrleveant_names()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.irrleveant_names()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message


def test9():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.reviews_dataset()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.reviews_dataset()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message

def test10():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    differences = []
    try:
        output = []
        try:
            output = user.remove_identical_rows()
        except Exception as e:
            message += str(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        test_output = test.remove_identical_rows()
        try:
            for column in output.columns:
                column1_df1 = output[column]
                column2_df2 = test_output[column]
                merged_df = pd.merge(column1_df1, column2_df2, left_index=True, right_index=True,
                                     suffixes=('_your_output', '_expected'), how='outer')

                column_differences = merged_df[~((merged_df[f'{column}_your_output'].eq(merged_df[f'{column}_expected'])) | (merged_df[f'{column}_your_output'].isnull() & merged_df[f'{column}_expected'].isnull()))]

                differences.append(column_differences)
        except Exception as e:
            print(e)
            lines = traceback.format_exc().splitlines()
            for line in lines:
                line = line.replace("/home/project/", "")
                print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))
            pass

        if len(output.columns) != len(test_output.columns):
            message1 = "Your columns in a dataframe do not match the expected dataframe columns"
            print(message1)
            print("Your columns:")
            print(output.columns)
            print("Expected columns:")
            print(test_output.columns)
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif output.shape[0] != test_output.shape[0]:
            message1 = "No. of rows in your dataframe is not matching with the expected dataframe"
            print(message1)
            print("Your rows count:")
            print(output.shape[0])
            print("Expected rows count:")
            print(test_output.shape[0])
            print("Your Output: ")
            print(output)
            print("\nExpected Output: ")
            print(test_output)
        elif all(len(column_diff) == 0 for column_diff in differences) and test_output.equals(output):
            ispassed = True
        else:
            print("<b>Following rows are not matching with expected rows</b>")
            print("<b>Data Differences:</b>")
            for column, column_diff in zip(output.columns, differences):
                if len(column_diff) > 0:
                    print(f"Differences in column '{column}':")
                    print(column_diff)
                    print()
        if ispassed:
            print("---------------------------------------------")
            print("No. of Rows and columns in Your Dataframe: ", output.shape)
            print("Your Updated results: ")
            print(output)
            print("No. of Rows and columns in Expected Dataframe: ", test_output.shape)
            print("\nExpected Output: ")
            print(test_output)
    except Exception as e:
        message = str(e)
        ispassed = False
        lines = traceback.format_exc().splitlines()
        for line in lines:
            line = line.replace("/home/project/", "")
            print(re.sub(r'File ".*[\\/]([^\\/]+.py)"', r'File "\1"', line))

        pass
    sys.stdout = sys.__stdout__

    message += op.getvalue()
    return ispassed, message

def test11():
    op = io.StringIO()
    sys.stdout = op
    ispassed = False
    message = ""
    try:
        table = "cleaned_apps_db"
        columns = "App, Category, Rating, Reviews, Installs, Type, Price,Genres"
        print("<b>verifying table: " + str(table) + "</b>")
        print("<b>Database loaded Successfully !!!!</b>")
        output, isdone = run_select_query("select " + columns + " from " + table + " limit 10")
        if isdone and len(output) == 10:
            ispassed = True
        else:
            ispassed = False
        if not ispassed:
            print('<b>"' + table + '" table not found with fields "' + columns + '" in your database</b>')
    except Exception as e:
        message = str(e)
        ispassed = False
        pass

    try:
        if ispassed:
            table = "cleaned_reviews_db"
            columns = "App,Translated_Review,Sentiment,Sentiment_Polarity,Sentiment_Subjectivity"
            print("<b>verifying table: " + str(table) + "</b>")
            print("<b>Database loaded Successfully !!!!</b>")
            output, isdone = run_select_query("select " + columns + " from " + table + " limit 10")
            if isdone and len(output) == 10:
                ispassed = True
            else:
                ispassed = False
            if not ispassed:
                print('<b>"' + table + '" table not found with fields "' + columns + '" in your database</b>')
    except Exception as e:
        message = str(e)
        ispassed = False
        pass
    sys.stdout = sys.__stdout__
    message += op.getvalue()
    return ispassed, message



if __name__ == "__main__":
    fileind = int(sys.argv[1])
    # fileind = 11
    print("Running Test case")
    message = ''
    ispassed = False
    try:
        if fileind == 1:
            ispassed, message = test1()
        elif fileind == 2:
            ispassed, message = test2()
        elif fileind == 3:
            ispassed, message = test3()
        elif fileind == 4:
            ispassed, message = test4()
        elif fileind == 5:
            ispassed, message = test5()
        elif fileind == 6:
            ispassed, message = test6()
        elif fileind == 7:
            ispassed, message = test7()
        elif fileind == 8:
            ispassed, message = test8()
        elif fileind == 9:
            ispassed, message = test9()
        elif fileind == 10:
            ispassed, message = test10()
        elif fileind == 11:
            ispassed, message = test11()

    except Exception as e:
        message = str(e)
        ispassed = False

    if ispassed:
        print("------------- Test Case <b>Passed</b> -------------")
    else:
        print("------------- Test Case <b>Failed</b> -------------")
    print(message)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 922
#     917     return ispassed, message
#     921 if __name__ == "__main__":
# --> 922     fileind = int(sys.argv[1])
#     923     # fileind = 11
#     924     print("Running Test case")
#
# ValueError: invalid literal for int() with base 10: '-f'
